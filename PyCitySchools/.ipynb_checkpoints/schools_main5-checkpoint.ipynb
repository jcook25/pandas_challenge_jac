# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
school_raw = "Resources/schools_complete.csv"
student_raw = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas Data Frames
scdf = pd.read_csv(school_raw)
stdf = pd.read_csv(student_raw)

# Combine the data into a single dataset
cdf = pd.merge(scdf, stdf, how="left", on=["school_name", "school_name"])
cdf.head(2)
# Out:
#    School ID        school_name      type  size   budget  Student ID  \
# 0          0  Huang High School  District  2917  1910635           0
# 1          0  Huang High School  District  2917  1910635           1
#
#    student_name gender grade  reading_score  math_score
# 0  Paul Bradley      M   9th             66          79
# 1  Victor Smith      M  12th             94          61

# %%
ccdf = cdf[['size', 'reading_score', 'math_score']]
ccdf = pd.DataFrame(ccdf)
ccdf['bps'] = cdf['budget'] / cdf['size']
ccdf['pm'] = cdf['math_score'] >= 70
ccdf['pr'] = cdf['reading_score'] >= 70
ccdf
# Out:
#        size  reading_score  math_score    bps     pm     pr
# 0      2917             66          79  655.0   True  False
# 1      2917             94          61  655.0  False   True
# 2      2917             90          60  655.0  False   True
# 3      2917             67          58  655.0  False  False
# 4      2917             97          84  655.0   True   True
# ...     ...            ...         ...    ...    ...    ...
# 39165  1635             99          90  638.0   True   True
# 39166  1635             95          70  638.0   True   True
# 39167  1635             73          84  638.0   True   True
# 39168  1635             99          90  638.0   True   True
# 39169  1635             95          75  638.0   True   True
#
# [39170 rows x 6 columns]

# %%
bins = [0, 1000, 2000, 5000]
group_names = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]
ccdf['School Size'] = pd.cut(ccdf["size"], bins, labels=group_names)
ccdf
# Out:
#        size  reading_score  math_score    bps     pm     pr  \
# 0      2917             66          79  655.0   True  False
# 1      2917             94          61  655.0  False   True
# 2      2917             90          60  655.0  False   True
# 3      2917             67          58  655.0  False  False
# 4      2917             97          84  655.0   True   True
# ...     ...            ...         ...    ...    ...    ...
# 39165  1635             99          90  638.0   True   True
# 39166  1635             95          70  638.0   True   True
# 39167  1635             73          84  638.0   True   True
# 39168  1635             99          90  638.0   True   True
# 39169  1635             95          75  638.0   True   True
#
#               School Size
# 0       Large (2000-5000)
# 1       Large (2000-5000)
# 2       Large (2000-5000)
# 3       Large (2000-5000)
# 4       Large (2000-5000)
# ...                   ...
# 39165  Medium (1000-2000)
# 39166  Medium (1000-2000)
# 39167  Medium (1000-2000)
# 39168  Medium (1000-2000)
# 39169  Medium (1000-2000)
#
# [39170 rows x 7 columns]

# %%
gbo = ccdf.groupby('School Size')
gbo.count().head()
# Out:
#                      size  reading_score  math_score    bps     pm     pr
# School Size
# Small (<1000)        1389           1389        1389   1389   1389   1389
# Medium (1000-2000)   8522           8522        8522   8522   8522   8522
# Large (2000-5000)   29259          29259       29259  29259  29259  29259

# %%
gdf = gbo.agg({  "reading_score":"mean",
                  "math_score":"mean", 
                  "pm":"sum", 
                  "pr":"sum"
               })
gdf['tc'] = gbo['size'].count()
gdf
# Out:
#                     reading_score  math_score       pm       pr     tc
# School Size
# Small (<1000)           83.974082   83.828654   1305.0   1334.0   1389
# Medium (1000-2000)      83.867989   83.372682   7978.0   8247.0   8522
# Large (2000-5000)       81.198674   77.477597  20087.0  24029.0  29259

# %%
gdf['% Passing Math'] = gdf.pm / gdf.tc
gdf['% Passing Reading'] = gdf.pr / gdf.tc
gdf['% Overall Passing Rate'] = (gdf['% Passing Reading'] + gdf['% Passing Math']) / 2
gdf
# Out:
#                     reading_score  math_score       pm       pr     tc  \
# School Size
# Small (<1000)           83.974082   83.828654   1305.0   1334.0   1389
# Medium (1000-2000)      83.867989   83.372682   7978.0   8247.0   8522
# Large (2000-5000)       81.198674   77.477597  20087.0  24029.0  29259
#
#                     % Passing Math  % Passing Reading  % Overall Passing Rate
# School Size
# Small (<1000)             0.939525           0.960403                0.949964
# Medium (1000-2000)        0.936165           0.967731                0.951948
# Large (2000-5000)         0.686524           0.821252                0.753888

# %%
fdf = gdf.rename(columns={'reading_score':'Average Reading Score',
                           'math_score':'Average Math Score'})

fdf = fdf[[ 'Average Math Score','Average Reading Score', '% Passing Math', '% Passing Reading', '% Overall Passing Rate']]

fdf.style
# Out:
# <style  type="text/css" >
# </style><table id="T_ef9b08e6_23bf_11ea_a810_982cbcbf4aae" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Average Math Score</th>        <th class="col_heading level0 col1" >Average Reading Score</th>        <th class="col_heading level0 col2" >% Passing Math</th>        <th class="col_heading level0 col3" >% Passing Reading</th>        <th class="col_heading level0 col4" >% Overall Passing Rate</th>    </tr>    <tr>        <th class="index_name level0" >School Size</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ef9b08e6_23bf_11ea_a810_982cbcbf4aaelevel0_row0" class="row_heading level0 row0" >Small (<1000)</th>
#                         <td id="T_ef9b08e6_23bf_11ea_a810_982cbcbf4aaerow0_col0" class="data row0 col0" >83.8287</td>
#                         <td id="T_ef9b08e6_23bf_11ea_a810_982cbcbf4aaerow0_col1" class="data row0 col1" >83.9741</td>
#                         <td id="T_ef9b08e6_23bf_11ea_a810_982cbcbf4aaerow0_col2" class="data row0 col2" >0.939525</td>
#                         <td id="T_ef9b08e6_23bf_11ea_a810_982cbcbf4aaerow0_col3" class="data row0 col3" >0.960403</td>
#                         <td id="T_ef9b08e6_23bf_11ea_a810_982cbcbf4aaerow0_col4" class="data row0 col4" >0.949964</td>
#             </tr>
#             <tr>
#                         <th id="T_ef9b08e6_23bf_11ea_a810_982cbcbf4aaelevel0_row1" class="row_heading level0 row1" >Medium (1000-2000)</th>
#                         <td id="T_ef9b08e6_23bf_11ea_a810_982cbcbf4aaerow1_col0" class="data row1 col0" >83.3727</td>
#                         <td id="T_ef9b08e6_23bf_11ea_a810_982cbcbf4aaerow1_col1" class="data row1 col1" >83.868</td>
#                         <td id="T_ef9b08e6_23bf_11ea_a810_982cbcbf4aaerow1_col2" class="data row1 col2" >0.936165</td>
#                         <td id="T_ef9b08e6_23bf_11ea_a810_982cbcbf4aaerow1_col3" class="data row1 col3" >0.967731</td>
#                         <td id="T_ef9b08e6_23bf_11ea_a810_982cbcbf4aaerow1_col4" class="data row1 col4" >0.951948</td>
#             </tr>
#             <tr>
#                         <th id="T_ef9b08e6_23bf_11ea_a810_982cbcbf4aaelevel0_row2" class="row_heading level0 row2" >Large (2000-5000)</th>
#                         <td id="T_ef9b08e6_23bf_11ea_a810_982cbcbf4aaerow2_col0" class="data row2 col0" >77.4776</td>
#                         <td id="T_ef9b08e6_23bf_11ea_a810_982cbcbf4aaerow2_col1" class="data row2 col1" >81.1987</td>
#                         <td id="T_ef9b08e6_23bf_11ea_a810_982cbcbf4aaerow2_col2" class="data row2 col2" >0.686524</td>
#                         <td id="T_ef9b08e6_23bf_11ea_a810_982cbcbf4aaerow2_col3" class="data row2 col3" >0.821252</td>
#                         <td id="T_ef9b08e6_23bf_11ea_a810_982cbcbf4aaerow2_col4" class="data row2 col4" >0.753888</td>
#             </tr>
#     </tbody></table>

# %%
print(gcdf.pm / gcdf.tc)
print(5967/6368)
print((.937+.966)/2)
# Out:
# Spending Ranges(Per Student)
# <$585       0.937029
# $585-615    0.941241
# $615-645    0.714004
# $645-675    0.662308
# dtype: float64
# 0.9370288944723618
# 0.9515
